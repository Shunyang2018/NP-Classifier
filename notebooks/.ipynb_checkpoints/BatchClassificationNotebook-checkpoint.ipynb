# %% [markdown]
# # CSV file to NP classification
# ## Change the parameter here:

# %%
csv = '/Users/shunyang.wang/project/SIRIUS/SIRIUS_utils/benchmark/pepsearch_tsv/IND.csv'# input csv
smi = 'smiles'# column name of smiles

# %%
import pandas as pd
import grequests
import urllib.parse
from tqdm import tqdm
import collections

# %%
SERVER_URL = "http://192.168.128.240:6541/"

df = pd.read_csv(csv)

all_urls = []

for entry in tqdm(df.to_dict(orient="records")):
    smiles = str(entry[smi])
    if len(smiles) > 5:
        request_url = "{}/classify?smiles={}".format(SERVER_URL, urllib.parse.quote(smiles))
        all_urls.append(request_url)

# Lets actually do the query and measure the speed
rs = (grequests.get(u) for u in all_urls)
responses = grequests.map(rs, size=20)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 115/115 [00:00<00:00, 211740.54it/s]

# %%
# get output dataframe
class_list = []
superclass = []
pathway = []
gly = []
for item in responses:
    try:
        tmp = item.json()
    except:
        tmp = {'class_results':'nan', 'superclass_results':'nan',
                  'pathway_results':'nan', 'isglycoside':'nan'}
    class_list.append(tmp['class_results'])
    superclass.append(tmp['superclass_results'])
    pathway.append(tmp['pathway_results'])
    gly.append(tmp['isglycoside'])
    
classfy = pd.DataFrame({'class_results':class_list, 'superclass_results':superclass,
                  'pathway_results':pathway, 'isglycoside':gly})

# %%
df2 = pd.concat([df,classfy],axis=1)

# %%
df2.to_csv(csv.replace('.csv','npclass.csv'),index=False)

# %%
df2
# Out:
#      Unnamed: 0.1  Unnamed: 0   Num  \
# 0               0         116  1201
# 1               1         190  1696
# 2               2         201  1849
# 3               3         202  1851
# 4               4         203  1852
# ..            ...         ...   ...
# 110           110         239  2293
# 111           111         240  2294
# 112           112         264  2602
# 113           113         291  2767
# 114           114         418  3614
#
#                                                Unknown  \
# 0    IND_HH_F_PFP_M4_P_CIDHCD_9092022_IDENTIFICATIO...
# 1    IND_HH_F_PFP_M4_P_CIDHCD_9092022_IDENTIFICATIO...
# 2    IND_HH_F_PFP_M4_P_CIDHCD_9092022_IDENTIFICATIO...
# 3    IND_HH_F_PFP_M4_P_CIDHCD_9092022_IDENTIFICATIO...
# 4    IND_HH_F_PFP_M4_P_CIDHCD_9092022_IDENTIFICATIO...
# ..                                                 ...
# 110  IND_HH_F_PFP_M2_P_CIDHCD_9092022_IDENTIFICATIO...
# 111  IND_HH_F_PFP_M2_P_CIDHCD_9092022_IDENTIFICATIO...
# 112  IND_HH_F_PFP_M2_P_CIDHCD_9092022_IDENTIFICATIO...
# 113  IND_HH_F_PFP_M2_P_CIDHCD_9092022_IDENTIFICATIO...
# 114  IND_HH_F_PFP_M2_P_CIDHCD_9092022_IDENTIFICATIO...
#
#                         InChIKey  Precursor m/z  Rank       Library        Id  \
# 0    IIRDTKBZINWQAW-UHFFFAOYSA-N       283.1750   1.0  hr_msms_nist   79551.0
# 1    RSWBWHPZXKLUEX-VOTSOKGWSA-N       145.0652   1.0  hr_msms_nist  308552.0
# 2    XEVQXKKKAVVSMW-WRWORJQWSA-N       197.1172   1.0  hr_msms_nist  722589.0
# 3    IJGMVUXEZUEDJR-RTWAVKEYSA-N       179.1060   1.0  hr_msms_nist  607212.0
# 4    LXOFYPKXCSULTL-UHFFFAOYSA-N       135.1162   1.0  hr_msms_nist  110830.0
# ..                           ...            ...   ...           ...       ...
# 110  AUJXJFHANFIVKH-GQCTYLIASA-N       177.0548   1.0  hr_msms_nist  306285.0
# 111  QAIPRVGONGVQAS-DUXPYHPUSA-N       145.0286   1.0  hr_msms_nist  187819.0
# 112  DOUMFZQKYFQNTF-WUTVXBCWSA-N       163.0385   1.0  hr_msms_nist  615285.0
# 113  FETSKTIMHFKZNF-AATRIKPKSA-N       175.1481   1.0  hr_msms_nist  915029.0
# 114  VBZSUWNESITEBV-KHBQWKRXSA-N       184.0730   1.0  hr_msms_nist  275763.0
#
#         Mass  ...  NIST r.n.  Num.Comp  mode  column  \
# 0    282.168  ...  1186838.0       9.0     P     PFP
# 1    162.068  ...  1525554.0     255.0     P     PFP
# 2    196.110  ...  3101076.0      57.0     P     PFP
# 3    234.162  ...  1948004.0     222.0     P     PFP
# 4    226.193  ...  1236765.0    1003.0     P     PFP
# ..       ...  ...        ...       ...   ...     ...
# 110  208.074  ...  1522011.0     705.0     P     PFP
# 111  180.042  ...  1350786.0      61.0     P     PFP
# 112  360.085  ...  1958528.0     609.0     P     PFP
# 113  192.151  ...  3347705.0      57.0     P     PFP
# 114  762.601  ...  1478740.0     220.0     P     PFP
#
#                                                  inchi  \
# 0    InChI=1S/C12H26O7/c13-1-3-15-5-7-17-9-11-19-12...
# 1    InChI=1S/C10H10O2/c1-8-4-2-3-5-9(8)6-7-10(11)1...
# 2    InChI=1S/C11H16O3/c1-10(2)5-7(12)6-11(3)8(10)4...
# 3    InChI=1S/C15H22O2/c1-9-11-4-5-12(13(16)17)15(1...
# 4    InChI=1S/C14H26O2/c1-11(2)9-13(5,15)7-8-14(6,1...
# ..                                                 ...
# 110  InChI=1S/C11H12O4/c1-14-10-7-8(3-5-9(10)12)4-6...
# 111  InChI=1S/C9H8O4/c10-7-3-1-6(5-8(7)11)2-4-9(12)...
# 112  InChI=1S/C18H16O8/c19-12-4-1-10(7-14(12)21)3-6...
# 113  InChI=1S/C13H20O/c1-9-7-10(2)13(11(3)8-9)6-5-1...
# 114  InChI=1S/C42H85NO8P/c1-7-10-12-14-16-18-20-22-...
#
#                                                 smiles  \
# 0                                  OCCOCCOCCOCCOCCOCCO
# 1                                 Cc1ccccc1/C=C/C(=O)O
# 2                 CC1(C)C[C@H](O)C[C@@]2(C)OC(=O)C=C12
# 3    C=C1[C@H]2CC[C@H](C(=O)O)[C@@]23CC[C@H](C3)C1(C)C
# 4                        CC(C)CC(C)(O)C#CC(C)(O)CC(C)C
# ..                                                 ...
# 110                        COC(=O)/C=C/c1ccc(O)c(OC)c1
# 111                          O=C(O)/C=C/c1ccc(O)c(O)c1
# 112  O=C(/C=C/c1ccc(O)c(O)c1)O[C@H](Cc1ccc(O)c(O)c1...
# 113                        CC(=O)/C=C/C1C(C)C=C(C)CC1C
# 114  CCCCCCCCCCCCCCCC(=O)OC[C@H](COP(=O)(OCC)OCC[N+...
#
#                         class_results          superclass_results  \
# 0                 [Monoacylglycerols]             [Glycerolipids]
# 1    [Cinnamic acids and derivatives]  [Phenylpropanoids (C6-C3)]
# 2               [Apocarotenoids (β-)]            [Apocarotenoids]
# 3          [Zizaane sesquiterpenoids]          [Sesquiterpenoids]
# 4                                  []                          []
# ..                                ...                         ...
# 110  [Cinnamic acids and derivatives]  [Phenylpropanoids (C6-C3)]
# 111  [Cinnamic acids and derivatives]  [Phenylpropanoids (C6-C3)]
# 112  [Cinnamic acids and derivatives]  [Phenylpropanoids (C6-C3)]
# 113                                []                          []
# 114          [Glycerophosphocholines]      [Glycerophospholipids]
#
#                        pathway_results isglycoside
# 0                        [Fatty acids]       False
# 1    [Shikimates and Phenylpropanoids]       False
# 2                         [Terpenoids]       False
# 3                         [Terpenoids]       False
# 4                         [Terpenoids]       False
# ..                                 ...         ...
# 110  [Shikimates and Phenylpropanoids]       False
# 111  [Shikimates and Phenylpropanoids]       False
# 112  [Shikimates and Phenylpropanoids]       False
# 113                       [Terpenoids]       False
# 114                      [Fatty acids]       False
#
# [115 rows x 36 columns]
